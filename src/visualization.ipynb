# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("../data/listeners_data.csv")
df_new = df.iloc[2:,:15]
df_new.head()
# Out:
#          Date  Azahriah  Pogány Induló  Elefánt  Moriones  Beton.Hofi  Co Lee  \
# 2  2024-10-08    703337         347213   121661    283255      318426  125226
# 3  2024-10-09    703134         347435   120989    282964      319658  126483
# 4  2024-10-11    703216         347547   120146    282529      320165  128495
# 5  2024-10-12    702537         346882   119588    282464      320188  129214
# 6  2024-10-13    703060         346284   119152    282816      320288  128765
#
#    Balkan VIP  Carson Coma     Krúbi   FRANKO  Analog Balaton  szolnoki  \
# 2     16882.0     185336.0  172157.0  41205.0         66037.0   27548.0
# 3     16765.0     183931.0  172145.0  41294.0         66311.0   27184.0
# 4     16384.0     181916.0  171793.0  41641.0         65802.0   26419.0
# 5     16481.0     181451.0  172054.0  41943.0         65504.0   25900.0
# 6     16507.0     180418.0  172205.0  42056.0         65327.0   25644.0
#
#    Wxlfless   Blaize
# 2   10871.0  76899.0
# 3   10857.0  78420.0
# 4   10605.0  81201.0
# 5   10463.0  82588.0
# 6   10352.0  82436.0

# %%
plt.plot(df_new.iloc[:,1:].astype(int)/df_new.iloc[0,1:].astype(int))
plt.legend(df.columns[1:],bbox_to_anchor=(-0.1, 0.9))
plt.grid()
plt.show()
